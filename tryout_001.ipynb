# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishchanda/bleep/blob/Dev/tryout_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ephem
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.8 MB/s eta 0:00:00
# ...

# %%
import ephem

# %%
mars = ephem.Mars()
mars.compute('10/20/2020')
print(mars.ra)
# Out:
# 17:51:14.50

# %%
mars.compute('2020/10/20')
print(mars.a_ra)
# Out:
# 1:13:48.77

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/LMMWNB_2002.csv')

# %%
df.head()
# Out:
#    Draw Date Winning Numbers  Mega Ball
# 0  9/25/2020  20 36 37 48 67         16
# 1  9/29/2020  14 39 43 44 67         19
# 2  10/2/2020  09 38 47 49 68         25
# 3  10/6/2020  15 16 18 39 59         17
# 4  10/9/2020  05 11 25 27 64         13
