# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishchanda/bleep/blob/Dev/Copy_of_19thDecMLOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MLOPS Theory : https://drive.google.com/file/d/1xbytjcA7Apaih1wLrqrArAL1MfFJusdH/view?usp=sharing

# %% [markdown]
# # MLOPS - Azure
# * **Azure** : It is a cloud platform which provice services
# * **Resource group** : Group of available resources which contains different workspaces(Dev,ML,SQL)
# * **For example**: A building with rooms where we can perform different task

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To get the homepage of Azure : https://portal.azure.com/

# %% [markdown]
# We have to search resource group: create one
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Azure ML Documentation : https://learn.microsoft.com/en-us/azure/machine-learning/?view=azureml-api-2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here Everything will be open to public
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Authoring section
# * Anything we are going create or build
# # Assets
# * Data and your belongings like Dataset, endpoints
# # Manage
# * All monitoring and computing(Core)

# %% [markdown]
# We will Create an compute instance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This process will take time
#
# Dataset link : https://drive.google.com/file/d/1EwKS2QJaemAadlVHRCeyglPIkU7IYMYA/view?usp=drive_link

# %% [markdown]
# Go to asset-->Data --> Create new
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on additional config settings
# * Select the metrices which helps you to judge the model
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Scroll Down --->
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Once submitted the training job---> Automate ML
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select---->Deploy---> Real time Endpoint

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Once you deploy:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Copy rest api link... and After 30 min..visit that link...you must be gettin some respsone( not Error)
