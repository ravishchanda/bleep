# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishchanda/bleep/blob/Dev/MLOPSDY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset link: https://drive.google.com/file/d/1wrh_rzuoI1HFpqzrMK7YMdkq0mjhLcEc/view?usp=drive_link

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/weatherHistory.csv')

# %%
df.head()

# %%
df['Daily Summary'].nunique()

# %%
df.shape

# %% [markdown]
# # After uploading the data and create the Virtual machine(Compute instance)
# * Authoring section ----> Designer
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Double click on clean missing data box(drag and drop ---- connect with next block)
# * Click on edit column
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Train Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Pipelines
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Jobs ---> Publish
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After Publishing ---- We will go to Pipelines
#
#
# ---
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For API Documentation : https://learn.microsoft.com/en-us/azure/machine-learning/concept-endpoints?view=azureml-api-2
